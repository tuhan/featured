# %% [markdown]
# # Web Scrape From Bitcoin Forum

# %%
import time
import pandas as pd
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
def parse_timestamp(timestamp_str):
    """
    Parse a timestamp string (e.g., "January 02, 2024, 02:36:13 PM")
    into a datetime object. Adjust the format string if needed.
    """
    try:
        return datetime.strptime(timestamp_str, "%B %d, %Y, %I:%M:%S %p")
    except Exception:
        return None

# %%
def scrape_topic_posts(driver, topic_url, subject_title, subsection):
    """
    Given a topic URL, visits the page (with ;all appended) and extracts all posts.
    For each post, extracts the timestamp and post content using the provided Relative XPath.
    Returns a list of dictionaries with keys: 'timestamp', 'post', 'subject', 'subsection'.
    """
    full_url = topic_url
    driver.get(full_url)
    time.sleep(3)  # Allow time for the page to load

    topic_posts = []
    # Locate all post containers within #quickModForm
    posts = driver.find_elements(
        "xpath", "//*[@id='quickModForm']/table[contains(@class,'bordercolor')]/tbody/tr"
    )

    if not posts:
        print("No posts found on topic page:", full_url)

    for p in posts:
        try:
            # Extract timestamp using the provided Relative XPath
            timestamp_text = p.find_element(
                "xpath", ".//td[2]/table/tbody/tr/td[2]/div[2]"
            ).text.strip()
            timestamp_obj = datetime.strptime(timestamp_text, "%B %d, %Y, %I:%M:%S %p")
            timestamp_text = timestamp_obj.strftime("%Y-%m-%d")
        except NoSuchElementException:
            timestamp_text = "No timestamp"

        try:
            # Extract post content using a more precise XPath
            post_text = p.find_element(
                "xpath", ".//td[2]/div[@class='post']"
            ).text.strip()
        except NoSuchElementException:
            post_text = "No content"

        topic_posts.append({
            "timestamp": timestamp_text,
            "post": post_text,
            "subject": subject_title,
            "subsection": subsection
        })

    return topic_posts

# %%
def scrape_subsection_topics(num_pages, board_prefix, start_subject_num, start_date_str, 
                             end_date_str, keywords):
    """
    Scrapes topics from a specific board (subsection) page that meet criteria:
      - The topic's last post timestamp is within the specified date range.
      - The topic title contains the given keyword (case-insensitive).
    
    For each matching topic, the function visits the topic's URL (with ;all appended)
    and extracts all posts (timestamp and post content).
    """
    start_date = datetime.strptime(start_date_str, "%Y-%m-%d")
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d")
    
    # Configure headless Chrome browser
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    driver = webdriver.Chrome(
        service=Service(ChromeDriverManager().install()),
        options=chrome_options
    )
    
    all_posts = []
    
    # Loop over board pages. Each page URL is formed using the subject_start_num (which increments by 40).
    for page in range(num_pages):
        subject_start_num = start_subject_num + page * 40
        board_url = f"{board_prefix}{subject_start_num}"
        print(f"Accessing board page: {board_url}")
        driver.get(board_url)
        time.sleep(3)
        
        # Extract topic rows from the board page.
        # The CSS selectors here assume that each topic is in a table row within a table with class "bordercolor".
        topic_rows = driver.find_elements(By.CSS_SELECTOR, "#bodyarea table.bordercolor tr")
        
        for row in topic_rows:
            try:
                # Locate the topic link element
                link = row.find_element(By.CSS_SELECTOR, "td a[href*='topic=']")
                title = link.text.strip()
                topic_url = link.get_attribute("href")
                
                # Locate the element that holds the last post timestamp.
                last_post_elem = row.find_element(By.CSS_SELECTOR, "td.windowbg2.lastpostcol span")
                # Extract the timestamp string (taking only the first line)
                last_post_text = last_post_elem.text.strip().split("\n")[0]
                topic_last_post = parse_timestamp(last_post_text)
                if topic_last_post is None:
                    continue
                
                # Filter topics by date range
                if not (start_date <= topic_last_post <= end_date):
                    continue
                
                # Filter by keyword (case-insensitive)
                #if keyword.lower() not in title.lower():
                #    subsection = keyword
                #    continue
                matched_coin = None
                for abbr, full_name in keywords.items():
                    if abbr.lower() in title.lower() or full_name.lower() in title.lower():
                        matched_coin = abbr  # Assign the abbreviation (e.g., "BTC")
                        break  # Stop checking after the first match
                
                # If no keyword match, skip this topic
                if not matched_coin:
                    continue
                
                subsection = matched_coin
                
                # Here, we set the subsection name. You might extract this differently.
                print(f"Scraping topic: {title} | Last post: {last_post_text}")
                
                # Scrape all posts from the topic
                topic_posts = scrape_topic_posts(driver, topic_url, title, subsection)
                all_posts.extend(topic_posts)
            except Exception as e:
                # If any error occurs in processing a row, skip it.
                continue
    
    driver.quit()
    df = pd.DataFrame(all_posts)
    return df

# %% [markdown]
# Due to the stucture of the website, bitcoin and alternative coins are scraped seperatly.

# %%
bitcoin = {
    "BTC": "Bitcoin"
}

df_bitcoin_posts = scrape_subsection_topics(num_pages=50,
                                           board_prefix="https://bitcointalk.org/index.php?board=1.",
                                           start_subject_num=380, 
                                           start_date_str="2024-01-01", 
                                           end_date_str="2024-12-31", 
                                           keywords=bitcoin)
# Out:
# Accessing board page: https://bitcointalk.org/index.php?board=1.380
# Scraping topic: Has Bitcoin met your expectations from the time you bought your Bitcoin till now | Last post: December 30, 2024, 07:35:51 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.420
# Scraping topic: Bitcoin is taxed up to 110% in Japan | Last post: December 30, 2024, 09:56:36 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.460
# Scraping topic: Is bitcoin slowly dying? | Last post: December 20, 2024, 02:31:47 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.500
# Scraping topic: one reason not to buy BitCoin | Last post: December 12, 2024, 02:03:07 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.540
# Scraping topic: BTC finally touch 100k+ milestone | Last post: December 05, 2024, 11:41:43 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.580
# Scraping topic: Bitcoin now more costly than a kilogram of gold | Last post: November 26, 2024, 07:25:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.620
# Scraping topic: What would a US recession do to the price of Bitcoin? | Last post: November 21, 2024, 05:01:30 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.660
# Scraping topic: Bitcoin Trump Bump = ~7% (womp womp) | Last post: November 11, 2024, 04:57:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.700
# Scraping topic: [DISCUSSION] Bitcoin Inheritance Planning | Last post: October 31, 2024, 02:59:36 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.740
# Scraping topic: Share Your Knowledge on Bitcoin and Altcoin | Last post: October 23, 2024, 02:02:23 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.780
# Scraping topic: Hiccups that can occur during Bitcoin investments. | Last post: October 16, 2024, 08:07:36 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.820
# Scraping topic: Bitcoin GALORE! meme Bounty(40 BTC) | Last post: October 02, 2024, 10:37:30 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.860
# Scraping topic: Not all Cryptocurrencies but Bitcoin is an asset. | Last post: September 22, 2024, 11:58:22 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.900
# Scraping topic: Do you sometimes get irritated by excess bitcoin fees ? | Last post: September 09, 2024, 07:48:35 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.940
# Scraping topic: All eyes On Trump As Kamal Harris Gives Up On Bitcoin Conference Attendance | Last post: August 26, 2024, 07:46:58 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.980
# Scraping topic: Can Bitcoin be a good investment over stocks in a recession period ? | Last post: August 13, 2024, 05:12:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1020
# Scraping topic: The US Factor: Why Bitcoin's Price is Tied to American News and Politics | Last post: August 03, 2024, 12:40:03 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1060
# Scraping topic: Big Bitcoin vs. Ethereum topic | Last post: July 25, 2024, 05:38:26 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1100
# Scraping topic: Suggest Practical Ways Someone Could Own One Bitcoin Starting from Zero in 2024 | Last post: July 16, 2024, 07:43:19 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1140
# Scraping topic: Regulating Bitcoin: Necessary Protection or Stifling Innovation? | Last post: July 05, 2024, 03:00:29 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1180
# Scraping topic: Have you successfully influenced someone to invest in bitcoin ? | Last post: June 25, 2024, 11:30:40 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1220
# Scraping topic: What are the benefits of accepting Bitcoin as a method of payment. | Last post: June 16, 2024, 04:48:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1260
# Scraping topic: Bitcoin security risk? How many miners make up 51% of the hashrate? | Last post: June 08, 2024, 06:12:47 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1300
# Scraping topic: Converting bitcoin to fiat without problems | Last post: May 29, 2024, 11:37:40 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1340
# Scraping topic: Number of new Bitcoin wallets drops to lowest level since 2018 | Last post: May 23, 2024, 12:35:58 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1380
# Scraping topic: Bitcoin negatives | Last post: May 13, 2024, 07:29:47 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1420
# Scraping topic: Bitcoin could have some innovations nowaday ? BRAINSTORMING COMMENTS | Last post: May 05, 2024, 11:00:46 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1460
# Scraping topic: Head of Research at Fidelity on Bitcoin VS Crypto | Last post: April 28, 2024, 12:50:44 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1500
# Scraping topic: == 2024 Bitcoin halving tribute puzzle - Challenge to win 10,000,000 sats! == | Last post: April 22, 2024, 07:02:52 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1540
# Scraping topic: In what currency other than the USD you know the price of Bitcoin by heart? | Last post: April 17, 2024, 07:28:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1580
# Scraping topic: To any Bitcoin holder who lost their seed: How did you lose it? | Last post: April 09, 2024, 02:57:04 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1620
# Scraping topic: Bitcoin feerates telegram notifications | Last post: March 29, 2024, 09:59:57 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1660
# Scraping topic: MicroStrategy acquires an additional 9,245 BTC with excess cash(@$67,382) | Last post: March 20, 2024, 05:11:17 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1700
# Scraping topic: Are people still using bitcoin ATMs? | Last post: March 11, 2024, 10:18:09 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1740
# Scraping topic: How did people buy bitcoin before Mt. Gox? | Last post: March 03, 2024, 07:36:07 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1780
# Scraping topic: Does it really cost $30 to mine one testnet bitcoin? | Last post: February 27, 2024, 03:05:27 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1820
# Scraping topic: BTC to Bitcoin ETFs - The ownership are shifting to centralized ownership | Last post: February 21, 2024, 07:23:53 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1860
# Scraping topic: Just bought FBTC in my 401k. First time ever holding crypto for retirement. | Last post: February 13, 2024, 03:49:54 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1900
# Scraping topic: Metamask now supporting bitcoin? | Last post: February 05, 2024, 10:23:51 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1940
# Scraping topic: The Global Impact of Bitcoin Remittances | Last post: January 29, 2024, 02:01:45 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.1980
# Scraping topic: What is the best thing that have ever come to you thanks to BTC | Last post: January 24, 2024, 02:16:09 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.2020
# Scraping topic: Did anyone else know there is an Insured BTC wallet? | Last post: January 18, 2024, 08:30:07 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.2060
# Scraping topic: [Poll] If Bitcoins blocks were 10x larger, would the miners be earning 10x? | Last post: January 13, 2024, 08:41:14 AM
# Accessing board page: https://bitcointalk.org/index.php?board=1.2100
# Scraping topic: Looking for someone who purchased bitcoin from 2011- *please respond to this" | Last post: January 07, 2024, 11:45:35 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.2140
# Scraping topic: emerging trends or projects in the Bitcoin space | Last post: January 02, 2024, 02:36:13 PM
# Accessing board page: https://bitcointalk.org/index.php?board=1.2180
# Accessing board page: https://bitcointalk.org/index.php?board=1.2220
# Accessing board page: https://bitcointalk.org/index.php?board=1.2260
# Accessing board page: https://bitcointalk.org/index.php?board=1.2300
# Accessing board page: https://bitcointalk.org/index.php?board=1.2340

# %%
df_bitcoin_posts.info()
df_bitcoin_posts.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timestamp   868 non-null    object
#  1   post        868 non-null    object
#  2   subject     868 non-null    object
#  3   subsection  868 non-null    object
# dtypes: object(4)
# memory usage: 27.3+ KB
#     timestamp                                               post  \
# 0  2024-11-05  You've been holding Bitcoin for many years and...
# 1  2024-11-05  Bitcoin has indeed exceeded my expectations. N...
# 2  2024-11-05  I would say Bitcoin has exceeded my expectatio...
# 3  2024-11-05  Quote from: Davidvictorson on November 05, 202...
# 4  2024-11-05  Quote from: Davidvictorson on November 05, 202...
#
#                                              subject subsection
# 0  Has Bitcoin met your expectations from the tim...        BTC
# 1  Has Bitcoin met your expectations from the tim...        BTC
# 2  Has Bitcoin met your expectations from the tim...        BTC
# 3  Has Bitcoin met your expectations from the tim...        BTC
# 4  Has Bitcoin met your expectations from the tim...        BTC

# %%
altcoin_namelist = {
    "ETH": "Ethereum",
    "XRP": "Ripple",
    "SOL": "Solana",
    "DOGE": "Dogecoin",
    "ADA": "Cardano",
    "TRX": "TRON",
    "XLM": "Stellar",
    "AVAX": "Avalanche",
    "SHIB": "Shiba Inu"
}

df_altcoin_posts = scrape_subsection_topics(num_pages=50, 
                                           board_prefix="https://bitcointalk.org/index.php?board=67.",
                                           start_subject_num=400, 
                                           start_date_str="2024-01-01", 
                                           end_date_str="2024-12-31", 
                                           keywords=altcoin_namelist)  # Pass as a dictionary
# Out:
# Accessing board page: https://bitcointalk.org/index.php?board=67.400
# Accessing board page: https://bitcointalk.org/index.php?board=67.440
# Scraping topic: Does intraday Trading actually works? | Last post: December 30, 2024, 09:16:21 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.480
# Scraping topic: 🟣INOFFICIAL SOLANA THREAD 🟣 [ Discuss everything about Solana here ] | Last post: December 23, 2024, 03:13:12 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.520
# Scraping topic: Ethereum fees | Last post: December 16, 2024, 10:23:42 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.560
# Scraping topic: Tron New ATH | Last post: December 09, 2024, 07:18:04 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.600
# Scraping topic: The Ethereum killer has been killed by Ripple hehehe | Last post: December 03, 2024, 03:05:57 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.640
# Scraping topic: Solana blockchain | Last post: November 28, 2024, 09:35:34 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.680
# Scraping topic: XRP Rally | Last post: November 23, 2024, 08:01:19 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.720
# Scraping topic: Solana Swap API and wallets question (for python coders) | Last post: November 17, 2024, 09:58:05 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.760
# Scraping topic: Elon Musk supports doge | Last post: November 14, 2024, 07:58:13 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.800
# Scraping topic: mETH Protocol | $COOK | AIR DROP ? | New currency steaking ? | Last post: November 03, 2024, 03:08:04 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.840
# Scraping topic: Why Are New Web3 Projects Launching at Lower Prices Despite Strong Features? | Last post: October 28, 2024, 08:15:45 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.880
# Scraping topic: Dogecoin is no longer just a memecoin | Last post: October 19, 2024, 09:33:59 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.920
# Scraping topic: Hivecoin Revolutionizes Markethive: The Future of Digital Marketing | Last post: October 10, 2024, 11:57:15 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.960
# Scraping topic: What did you think about the future of dogecoin? | Last post: September 27, 2024, 09:38:06 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1000
# Scraping topic: Are there any meme coins that come close to DOGE's popularity? | Last post: September 23, 2024, 02:29:45 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1040
# Scraping topic: Yes, XRP CAN Reach $10,000 Per Coin, but There's a Major Catch... | Last post: September 17, 2024, 06:07:55 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1080
# Scraping topic: The main problem with ETH... | Last post: September 12, 2024, 11:52:19 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1120
# Scraping topic: Is ETH a commodity now? | Last post: September 03, 2024, 10:37:50 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1160
# Scraping topic: Algorithmic stablecoin USDD - a risk to Tron, TRX, and the entire crypto market? | Last post: August 27, 2024, 09:57:10 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1200
# Scraping topic: Cardano will have Hydra & Chang, will ADA price to the moon soon? | Last post: August 17, 2024, 06:30:43 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1240
# Scraping topic: TIME FOR ETH MEMECOINS TO THRIVE? | Last post: August 09, 2024, 01:30:59 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1280
# Scraping topic: Will spot ETH ETF trigger altseason? | Last post: July 26, 2024, 06:01:43 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1320
# Scraping topic: How Can I cross bridge between Ethereum and Layer 2 Network? | Last post: July 19, 2024, 02:12:01 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1360
# Scraping topic: Which decentralized cloud storage solution is best? (2024) | Last post: July 12, 2024, 11:51:33 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1400
# Scraping topic: Dexscreener / Solana Meme Coins | Last post: June 28, 2024, 10:46:39 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1440
# Scraping topic: Solana price predictions and developement? | Last post: June 20, 2024, 11:17:43 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1480
# Scraping topic: How can I hide the source of my Ether without Tornado Cash? | Last post: June 15, 2024, 12:53:52 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1520
# Scraping topic: Since nakamoto is born - I understand that every shitcoin = altcoin = eth ??? | Last post: June 08, 2024, 12:59:13 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1560
# Scraping topic: Trading ripples(XRP) for Litecoin(LTC) | Last post: June 04, 2024, 11:50:57 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1600
# Scraping topic: Kabosu (Doge) passed away. | Last post: May 31, 2024, 07:24:58 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1640
# Scraping topic: Creating alt coin or what solution can i find | Last post: May 28, 2024, 01:11:58 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1680
# Scraping topic: The Remarkable Tale of Michael Nakamoto and the Lost Dogecoin Password | Last post: May 23, 2024, 06:03:23 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1720
# Scraping topic: Crypto Bull Run Approaching: Projects to Watch Besides ETH | Last post: May 17, 2024, 03:39:26 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1760
# Scraping topic: Does Interacting with Solana Dapps also require revoking approvals afterward? | Last post: May 10, 2024, 05:28:14 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1800
# Scraping topic: I Got 1 Million $SHIB airdroped in a trading competition! What Should I do? | Last post: May 06, 2024, 02:37:31 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1840
# Scraping topic: EPIK the next Solana meme sensation? | Last post: May 01, 2024, 06:01:55 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1880
# Scraping topic: Only1 has raised $5 million to build an OnlyFans clone on Solana | Last post: April 24, 2024, 04:45:07 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1920
# Scraping topic: Dogecoin (DOGE) | Last post: April 19, 2024, 04:09:39 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.1960
# Scraping topic: MNN: The Next Cryptocurrency Aiming to Dethrone Zephyr (ZEPH) | Last post: April 13, 2024, 07:55:35 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2000
# Scraping topic: Could This Solve Blockchain Gaming's Biggest Problems? | Last post: April 09, 2024, 12:52:05 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2040
# Scraping topic: Let's talk about SOL resilience for recent market correction | Last post: April 01, 2024, 12:10:23 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2080
# Scraping topic: NEWBY MISTAKE. WETH SENT FROM COINBASE WALLET TO COINBASE | Last post: March 29, 2024, 05:02:20 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2120
# Scraping topic: Starknet and Etherfi | Last post: March 23, 2024, 09:26:14 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2160
# Scraping topic: Which of the Wallet is the Best For Ethereum? | Last post: March 19, 2024, 03:59:32 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2200
# Scraping topic: How to move tokens from DEX with Ridiculous Eth gas fees.. gwei 100+ ?? | Last post: March 15, 2024, 07:22:36 AM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2240
# Scraping topic: best way to exchange token to eth | Last post: March 11, 2024, 10:55:35 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2280
# Scraping topic: Ethereum price for this month | Last post: March 06, 2024, 10:27:44 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2320
# Scraping topic: ETH3.0 Launch | Last post: March 02, 2024, 06:06:18 PM
# Accessing board page: https://bitcointalk.org/index.php?board=67.2360
# Scraping topic: Chapter 2 - Solana Mobile | Last post: February 25, 2024, 05:25:47 AM

# %%
df_altcoin_posts.info()
df_altcoin_posts.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timestamp   658 non-null    object
#  1   post        658 non-null    object
#  2   subject     658 non-null    object
#  3   subsection  658 non-null    object
# dtypes: object(4)
# memory usage: 20.7+ KB
#     timestamp                                               post  \
# 0  2024-12-30  Now I've been in crypto since 2022. I noticed ...
# 1  2024-12-30  Quote from: Novachrono2022 on December 30, 202...
# 2  2024-12-30  Quote from: Novachrono2022 on December 30, 202...
# 3  2024-12-30  Quote from: Novachrono2022 on December 30, 202...
# 4  2024-12-30  Quote from: Novachrono2022 on December 30, 202...
#
#                                  subject subsection
# 0  Does intraday Trading actually works?        ADA
# 1  Does intraday Trading actually works?        ADA
# 2  Does intraday Trading actually works?        ADA
# 3  Does intraday Trading actually works?        ADA
# 4  Does intraday Trading actually works?        ADA

# %%
# combine dataframes
df_crypto_posts = pd.concat([df_bitcoin_posts, df_altcoin_posts], ignore_index=True)

# %% [markdown]
# # NLP
#
# 1. Text Cleaning
# 2. Sentiment & Polarity Acore Calculations

# %%
# %pip install textblob
# %pip install re
# Out:
# Requirement already satisfied: textblob in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\sherlock pi\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\sherlock pi\appdata\roaming\python\python313\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
import pandas as pd
import re
from textblob import TextBlob

# Function to clean text
def clean_text(text):
    # Remove quoted messages (common in forum posts)
    text = re.sub(r'Quote from: .*?\n', '', text, flags=re.DOTALL)
    
    # Remove extra newlines and multiple spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# Function to compute sentiment polarity and subjectivity
def compute_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity, blob.sentiment.subjectivity

# %%
# Load DataFrame
df_crypto_posts['cleaned_post'] = df_crypto_posts['post'].apply(clean_text)

# Apply sentiment analysis on cleaned text
df_crypto_posts[['polarity', 'subjectivity']] = df_crypto_posts['cleaned_post'].apply(
    lambda txt: pd.Series(compute_sentiment(txt))
)

# %%
# Display the updated DataFrame
df_crypto_posts.info()
print(df_crypto_posts.head())

# Save to json
df_crypto_posts.to_json("crypto_posts.json", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1526 entries, 0 to 1525
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     1526 non-null   object
#  1   post          1526 non-null   object
#  2   subject       1526 non-null   object
#  3   subsection    1526 non-null   object
#  4   cleaned_post  1526 non-null   object
#  5   polarity      1526 non-null   float64
#  6   subjectivity  1526 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 83.6+ KB
#     timestamp                                               post  \
# 0  2024-11-05  You've been holding Bitcoin for many years and...
# 1  2024-11-05  Bitcoin has indeed exceeded my expectations. N...
# 2  2024-11-05  I would say Bitcoin has exceeded my expectatio...
# 3  2024-11-05  Quote from: Davidvictorson on November 05, 202...
# 4  2024-11-05  Quote from: Davidvictorson on November 05, 202...
#
#                                              subject subsection  \
# 0  Has Bitcoin met your expectations from the tim...        BTC
# 1  Has Bitcoin met your expectations from the tim...        BTC
# 2  Has Bitcoin met your expectations from the tim...        BTC
# 3  Has Bitcoin met your expectations from the tim...        BTC
# 4  Has Bitcoin met your expectations from the tim...        BTC
#
#                                         cleaned_post  polarity  subjectivity
# 0  You've been holding Bitcoin for many years and...  0.135333      0.522667
# 1  Bitcoin has indeed exceeded my expectations. N...  0.153409      0.562973
# 2  I would say Bitcoin has exceeded my expectatio...  0.408333      0.344444
# 3  My question to you is when you look back and s...  0.079861      0.553472
# 4  You've been holding Bitcoin for many years and...  0.040833      0.373426
